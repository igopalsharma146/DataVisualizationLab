# %% [markdown]
# # Matplotlib and Seaborn

# %%
import matplotlib.pyplot as plt
yield_apples=[0.895,0.91,0.919,0.926,0.929,0.931]
plt.plot(yield_apples)
plt.show()

# %%
years=[2010,2011,2012,2013,2014,2015]
yield_apples=[0.895,0.91,0.919,0.926,0.929,0.931]
plt.plot(years,yield_apples)
plt.show()

# %%
years=range(2000,2012)
apples=[0.895,0.91,0.919,0.926,0.929,0.931,0.934,0.936,0.937,0.9375,0.9372,0.939]
oranges=[0.962,0.941,0.930,0.923,0.918,0.908,0.907,0.904,0.901,0.898,0.9,0.896]

plt.plot(years,apples)
plt.plot(years,oranges)
plt.xlabel("Year")
plt.ylabel("Yield(tons per hectare.)")
plt.show()

# %%
plt.plot(years,apples)
plt.plot(years,oranges)
plt.xlabel("Year")
plt.ylabel("Yield(tons per hectare.)")

plt.title("Crop Yields in Kanto")
plt.legend(['Apples','Oranges'])
plt.show()

# %%
plt.plot(years,apples,marker="o")
plt.plot(years,oranges,marker="x")

plt.xlabel("Year")
plt.ylabel("Yield(tons per hectare.)")

plt.title("Crop Yields in Kanto")
plt.legend(['Apples','Oranges'])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(years,oranges,marker="o")
plt.ylabel("Yield of oranges(tons per hectare.)")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

plt.plot(years,apples,marker="o")
plt.plot(years,oranges,marker="x")

plt.xlabel("Year")
plt.ylabel("Yield(tons per hectare.)")

plt.title("Crop Yields in Kanto")
plt.legend(['Apples','Oranges'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

plt.plot(years,apples,marker="o")
plt.plot(years,oranges,marker="x")

plt.xlabel("Year")
plt.ylabel("Yield(tons per hectare.)")

plt.title("Crop Yields in Kanto")
plt.legend(['Apples','Oranges'])
plt.show()

# %% [markdown]
# # Bar Graphs

# %%
years=range(2000,2006)
apples=[0.35,0.6,0.9,0.7,0.5,0.8]
oranges=[0.4,0.8,0.9,0.7,0.6,0.8]

plt.bar(years,oranges)
plt.xlabel('Year')
plt.ylabel("Yield(tons per hectare.)")

plt.title("Crop Yields in Kanto")
plt.show()

# %%
plt.bar(years,oranges)
plt.bar(years,oranges,bottom=apples)
# Out:
# <BarContainer object of 6 artists>

# %%
# Lets use the tips dataset in seaborn next.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips_df=sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='day',y='total_bill',data=tips_df)
plt.show()

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=tips_df)
plt.show()

# %%
sns.barplot(x='total_bill',y='day',hue='sex',data=tips_df)
plt.show()

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns
flowers_df=sns.load_dataset("iris")
flowers_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df.sepal_width)
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
# Specifying the number of bins
plt.hist(flowers_df.sepal_width,bins=5)
# Out:
# (array([11., 46., 68., 21.,  4.]),
#  array([2.  , 2.48, 2.96, 3.44, 3.92, 4.4 ]),
#  <BarContainer object of 5 artists>)

# %%
import numpy as np
#Specifying the boundaries of each bins
plt.hist(flowers_df.sepal_width,bins=np.arange(2,5,0.25))
# Out:
# (array([ 4.,  7., 22., 24., 50., 18., 13.,  8.,  3.,  1.,  0.]),
#  array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#         4.75]),
#  <BarContainer object of 11 artists>)

# %%
# bins the uniqual sizes
plt.hist(flowers_df.sepal_width,bins=[1,3,4,4.5])
# Out:
# (array([57., 89.,  4.]),
#  array([1. , 3. , 4. , 4.5]),
#  <BarContainer object of 3 artists>)

# %%
santosa_df=flowers_df[flowers_df.species=='setosa']
versicolor_df=flowers_df[flowers_df.species=='versicolor']
virginica_df=flowers_df[flowers_df.species=='virginica']

plt.hist(santosa_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25))
plt.hist(versicolor_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25))
# Out:
# (array([ 3.,  6., 12., 13., 14.,  2.,  0.,  0.,  0.,  0.,  0.]),
#  array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#         4.75]),
#  <BarContainer object of 11 artists>)

# %%
plt.title("Distribution of Sepal width")

plt.hist([santosa_df.sepal_width,versicolor_df.sepal_width,virginica_df.sepal_width],
         alpha=0.4,bins=np.arange(2,5,0.25),stacked=True)
plt.legend(['santosa','versicolor','virginica'])

# %% [markdown]
# # Scatter Plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
flowers_df=sns.load_dataset("iris")
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flowers_df.sepal_length,flowers_df.sepal_width)

# %%
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width,
                hue=flowers_df.species,s=70)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(12,6))
plt.title('Sepal Dimensions')
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width,
                hue=flowers_df.species,s=100)
# Out:
# <Axes: title={'center': 'Sepal Dimensions'}, xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
var2=sns.load_dataset("anagrams")
var2
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
x=var2.drop(columns="attnr",axis=1).head(10)
x
# Out:
#    subidr  num1  num2  num3
# 0       1     2   4.0     7
# 1       2     3   4.0     5
# 2       3     3   5.0     6
# 3       4     5   7.0     5
# 4       5     4   5.0     8
# 5       6     5   5.0     6
# 6       7     5   4.5     6
# 7       8     5   7.0     8
# 8       9     2   3.0     7
# 9      10     6   5.0     6

# %%
sns.heatmap(x)
# Out:
# <Axes: >

# %%
sns.heatmap(x,vmin=0,vmax=10,cmap="gist_heat",annot=True)
plt.show()
