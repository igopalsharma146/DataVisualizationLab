# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
data = sns.load_dataset('iris')

# Trend line with confidence interval
sns.lmplot(x='sepal_length', y='sepal_width', data=data, ci=95)
plt.title('Trend Line with Confidence Band')
plt.show()
